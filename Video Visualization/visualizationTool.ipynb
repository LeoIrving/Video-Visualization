# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pose_df = pd.read_csv("pose.csv")

# %%
pose_df
# Out:
#             X         Y         Z
# 0   -1.566587  0.167575 -0.472210
# 1   -1.566330  0.167501 -0.472520
# 2   -1.566155  0.167335 -0.472940
# 3   -1.566104  0.167317 -0.473146
# 4   -1.566151  0.167413 -0.473105
# ..        ...       ...       ...
# 889 -1.475431  1.195731 -0.478753
# 890 -1.475756  1.195880 -0.478443
# 891 -1.476147  1.196291 -0.477890
# 892 -1.476397  1.196562 -0.477193
# 893 -1.476544  1.196751 -0.476387
#
# [894 rows x 3 columns]

# %%
fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111,projection='3d')
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
i = 1
for row in pose_df.iterrows():
    Color = [i*5/255,i*5/255,i*10/255]
    ax.scatter(row[1][0],row[1][1],row[1][2],s=10,color=Color, marker='x')
    i = i+ 0.1
    if i >25.5:
        i = 1
ax.view_init(-120, 60)
plt.show()
